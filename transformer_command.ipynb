# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejaswi4563/AI-Agent/blob/main/transformer_command.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

# %%
a = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# ...

# %%
text = input("enter the text:")
print(a(text))
# Out:
# enter the text:its cool
# [{'label': 'POSITIVE', 'score': 0.9998533725738525}]

# %%
gen = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
text = input("enter the text:")
t = gen(text, max_length = 200)
# Out:
# enter the text:once upon a time
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
print(t[0].get('generated_text'))
# Out:
# once upon a time when we're in a pretty good position with our relationship with the world. He's certainly been a real inspiration, and this isn't going to be about what we can say; we're going to focus on the world, on what has taken so long.
#
# We always try to play our part and we know we can do so. It makes it all better that we can do more than the people, the music and the people that want and expect us to. But I personally want to see the world as a platform and as a friend. I want to see things in our own way come together and change things, and that's where the opportunity to live and work in this community is.
#
# When I look at my wife, I see her at a crossroads—to be a successful mother, to live and give back, to be a champion and get out and make a difference. I was there in those moments, but after I met her, I

# %%
n = pipeline('ner')
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# ...

# %%
text = input("enter a text")
result = n(text)
(result)
# Out:
# enter a texti am tejaswi from vignan university vadlamudi
# [{'entity': 'I-MISC',
#   'score': np.float32(0.5131934),
#   'index': 4,
#   'word': '##jas',
#   'start': 7,
#   'end': 10},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.63226944),
#   'index': 8,
#   'word': '##ign',
#   'start': 19,
#   'end': 22},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.48131868),
#   'index': 12,
#   'word': '##ad',
#   'start': 37,
#   'end': 39},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.5341544),
#   'index': 13,
#   'word': '##lam',
#   'start': 39,
#   'end': 42}]

# %%
qa = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# ...

# %%
c = '''Bity bought some butter, but the butter was bitter butter.
so, Bitty bought some better butter, to make bitter butter better'''

# %%
q = "what does Bitty bought?"

# %%
result = qa({'question': q, 'context': c})
print(result)
# Out:
# {'score': 0.20272742211818695, 'start': 76, 'end': 94, 'answer': 'some better butter'}

# %%
s = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Device set to use cpu

# %%
t = '''Artificial Intelligence (AI) is one technical force that stands out in the dynamic field of computer engineering for its disruptive influence. The use of AI in computer engineering is changing the way we engage with technology as we traverse the digital age. It opens up new possibilities and transforms the way we see the world. This essay examines the complex connections between AI, AI in computer engineering, and machine learning's critical role in determining the direction of the discipline.
Artificial Intelligence: A Novel Approach to Computer Science
The field of computer science known as artificial intelligence, or AI, seeks to build intelligent robots that can mimic human cognitive processes.
AI is a game-changer in computer engineering, providing answers that go beyond conventional programming. Its capacity for pattern analysis, data mining, and decision-making gives up a wide range of opportunities for developing intelligent systems and cutting-edge applications.
1. Artificial Intelligence in Computer Engineering: The Innovation Engine
The old paradigms of automation and problem-solving have been changed by the introduction of AI into computer engineering. AI technologies are used by computer engineers to create intelligent systems that are capable of learning, adapting, and streamlining workflows. The uses of artificial intelligence (AI) in computer engineering are numerous and varied, ranging from voice recognition and image processing to autonomous cars and predictive analytics.
2. Machine Learning: Computer Engineering's AI Core
Machine Learning (ML), a subset of AI that enables computers to learn from data without explicit programming, is at the center of the field. Machine learning algorithms are essential to data analysis, predictive modeling, and decision-making in computer engineering. Systems are able to adapt to changing situations and perform better over time because of this dynamic approach.
Marching Towards the Future with MITAOE: An AI Education Hub
Choosing the correct school becomes crucial in the middle of the revolutionary AI wave in computer engineering. An excellent place for prospective computer engineers to learn about the complexities of artificial intelligence is the MIT Academy of Engineering (MITAOE) in Pune.'''

# %%
result = s(t)
print(result[0].get('summary_text'))
# Out:
#  Artificial Intelligence (AI) is one technical force that stands out in the dynamic field of computer engineering for its disruptive influence . The use of AI in computer engineering is changing the way we engage with technology as we traverse the digital age . Machine Learning (ML) enables computers to learn from data without explicit programming .

# %%
u = pipeline('fill-mask')
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# ...

# %%
result = u("I'm lisenting <mask> the board")
result
# Out:
# [{'score': 0.3977518379688263,
#   'token': 420,
#   'token_str': ' across',
#   'sequence': "I'm lisenting across the board"},
#  {'score': 0.10664219409227371,
#   'token': 15,
#   'token_str': ' on',
#   'sequence': "I'm lisenting on the board"},
#  {'score': 0.10348395258188248,
#   'token': 2500,
#   'token_str': ' onto',
#   'sequence': "I'm lisenting onto the board"},
#  {'score': 0.06812159717082977,
#   'token': 160,
#   'token_str': ' off',
#   'sequence': "I'm lisenting off the board"},
#  {'score': 0.03193071857094765,
#   'token': 198,
#   'token_str': ' around',
#   'sequence': "I'm lisenting around the board"}]
